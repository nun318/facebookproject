# %%
import pandas as pd
import numpy as np # numpy

# %%
face=pd.read_csv('Downloads/temp_datalab_records_social_facebook.csv', header=0)
link=pd.read_csv('Downloads/temp_datalab_records_linkedin_company.csv', header=0)

# %%
print(link.head())
# Out:
#    dataset_id  as_of_date            company_name  followers_count  \
# 0       58329  2015-09-14           Goldman Sachs           552254
# 1       58329  2015-09-15           Goldman Sachs           552862
# 2       58363  2015-09-16     United Technologies            59157
# 3       58366  2015-09-16            Novo Nordisk           336175
# 4       58371  2015-09-16  Lowe's Companies, Inc.           134255
#
#    employees_on_platform                                   link  \
# 0                  38124  https://www.linkedin.com/company/1382
# 1                  38141  https://www.linkedin.com/company/1382
# 2                  14982  https://www.linkedin.com/company/2426
# 3                  26448  https://www.linkedin.com/company/2227
# 4                  62574  https://www.linkedin.com/company/4128
#
#                industry              date_added            date_updated  \
# 0    Investment Banking  2015-09-14 00:00:00+00  2015-09-14 00:00:00+00
# ...

# %%
print(face.head())
# Out:
#    dataset_id                    time              username  checkins  \
# 0       53088  2015-01-01 05:00:00+00            SodaStream         0
# 1       52642  2015-01-01 05:00:00+00              ANSYSInc       148
# 2       53656  2015-01-01 05:00:00+00         MyAquaAmerica         0
# 3       53033  2015-01-01 05:00:00+00              Qualcomm       173
# 4       52783  2015-01-01 05:00:00+00  eaglepharmaceuticals         0
#
#   has_added_app  were_here_count    likes  talking_about_count  \
# 0             f                0   761533                  587
# 1             f                0    43442                 1305
# 2             f                0     5591                  297
# 3             f                0  1232521                 2685
# 4             f                0       18                    0
#
#         facebook_id date_added                   date_updated  entity_id  \
# 0       54885616308        NaN  2017-02-14 03:35:13.236826+00        NaN
# ...

# %%
face.describe()
# Out:
#          dataset_id      checkins  were_here_count         likes  \
# count  3.621391e+06  3.621391e+06     3.621391e+06  3.621391e+06
# mean   2.728824e+05  1.417013e+04     1.356737e+05  8.166253e+05
# std    3.888200e+05  2.326502e+05     1.330491e+06  4.937245e+06
# min    5.261200e+04  0.000000e+00     0.000000e+00  1.000000e+00
# 25%    5.361000e+04  0.000000e+00     0.000000e+00  2.500000e+03
# 50%    6.361600e+04  1.300000e+01     0.000000e+00  2.047700e+04
# 75%    9.057400e+04  2.860000e+02     1.140000e+02  2.175790e+05
# max    2.340089e+06  1.729055e+07     3.682637e+07  2.106411e+08
#
#        talking_about_count   facebook_id  entity_id  cusip  isin
# count         3.621391e+06  3.621391e+06        0.0    0.0   0.0
# mean          1.004266e+04  1.737944e+14        NaN    NaN   NaN
# std           7.292689e+04  4.413697e+14        NaN    NaN   NaN
# min           0.000000e+00  5.181544e+09        NaN    NaN   NaN
# ...

# %%
link.describe()
# Out:
#          dataset_id  followers_count  employees_on_platform  entity_id  cusip  \
# count  2.426196e+06     2.426196e+06           2.426196e+06        0.0    0.0
# mean   7.347932e+05     7.167738e+04           7.587255e+03        NaN    NaN
# std    5.004440e+05     2.638344e+05           2.412444e+04        NaN    NaN
# min    5.832900e+04     0.000000e+00           0.000000e+00        NaN    NaN
# 25%    6.851400e+04     2.148000e+03           2.180000e+02        NaN    NaN
# 50%    8.790880e+05     9.335000e+03           1.083000e+03        NaN    NaN
# 75%    9.029690e+05     3.864200e+04           4.513000e+03        NaN    NaN
# max    2.339486e+06     7.833967e+06           5.779520e+05        NaN    NaN
#
#        isin
# count   0.0
# mean    NaN
# std     NaN
# min     NaN
# 25%     NaN
# 50%     NaN
# 75%     NaN
# max     NaN

# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas-datareader
# Out:
# ...
#      |████████████████████████████████| 112kB 1.6MB/s eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas_datareader.data as web

import pandas as pd
import numpy as np
import datetime
# %matplotlib inline

# %%
start = datetime.datetime(2015, 1, 1)
end = datetime.datetime(2018, 7, 17)

# %%
BAC = data.DataReader("BAC", 'yahoo', start, end)

# CitiGroup
C = data.DataReader("C", 'yahoo', start, end)

# Goldman Sachs
GS = data.DataReader("GS", 'yahoo', start, end)

# JPMorgan Chase
JPM = data.DataReader("JPM", 'yahoo', start, end)

# Morgan Stanley
MS = data.DataReader("MS", 'yahoo', start, end)

# Wells Fargo
WFC = data.DataReader("WFC", 'yahoo', start, end)

#Starbucks
SBUX=data.DataReader("SBUX", 'yahoo', start, end)

#Dunkin Donuts
DNKN=data.DataReader("DNKN", 'yahoo', start, end)

# %%
banktickers = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']
coffeetickers = ['SBUX', 'DNKN']

# %%
coffee_stocks = pd.concat([SBUX, DNKN],axis=1,keys=coffeetickers)

# %%
coffee_stocks.columns.names = ['Coffee Ticker','Stock Info']

# %%
coffee_stocks.head()
# Out:
# Coffee Ticker       SBUX                                               \
# Stock Info          High        Low       Open      Close      Volume
# Date
# 2015-01-02     41.490002  40.445000  41.064999  40.720001   6886000.0
# 2015-01-05     40.334999  39.744999  40.070000  39.939999  11623800.0
# 2015-01-06     40.195000  39.279999  40.169998  39.615002   7664400.0
# 2015-01-07     40.615002  39.700001  39.875000  40.590000   9732600.0
# 2015-01-08     41.650002  41.009998  41.165001  41.244999  13170600.0
#
# Coffee Ticker                  DNKN                                   \
# Stock Info     Adj Close       High        Low       Open      Close
# Date
# 2015-01-02     37.132599  43.070000  42.230000  42.910000  42.730000
# 2015-01-05     36.421303  42.830002  41.720001  42.730000  42.470001
# 2015-01-06     36.124943  43.090000  42.000000  42.669998  42.320000
# 2015-01-07     37.014053  43.650002  42.549999  42.619999  43.540001
# ...

# %%
coffee_stocks.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Coffee Ticker
# SBUX    64.570000
# DNKN    72.169998
# dtype: float64

# %%
returns = pd.DataFrame()

# %%
for tick in coffeetickers:
    returns[tick+' Return'] = coffee_stocks[tick]['Close'].pct_change()
returns.head()
# Out:
#             SBUX Return  DNKN Return
# Date
# 2015-01-02          NaN          NaN
# 2015-01-05    -0.019155    -0.006085
# 2015-01-06    -0.008137    -0.003532
# 2015-01-07     0.024612     0.028828
# 2015-01-08     0.016137     0.008039

# %%
#returns[1:]
import seaborn as sns
sns.pairplot(returns[1:])

# %%
returns.idxmin()
# Out:
# SBUX Return   2017-07-28
# DNKN Return   2015-10-01
# dtype: datetime64[ns]

# %%
returns.idxmax()
# Out:
# SBUX Return   2015-01-23
# DNKN Return   2015-04-23
# dtype: datetime64[ns]

# %%
returns.std()
# Out:
# SBUX Return    0.013015
# DNKN Return    0.014030
# dtype: float64

# %%
sns.distplot(returns.ix['2015-01-03':'2018-01-01']['SBUX Return'],color='green',bins=100)
# Out:
# /Users/yanyan/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
sns.distplot(returns.ix['2015-01-03':'2018-01-01']['DNKN Return'],color='red',bins=100)
# Out:
# /Users/yanyan/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %%
for tick in coffeetickers:
    coffee_stocks[tick]['Close'].plot(figsize=(12,4),label=tick)
plt.legend()

# %%
plt.figure(figsize=(12,6))
SBUX['Close'].ix['2015-01-03':'2018-07-01'].rolling(window=30).mean().plot(label='30 Day Avg')
SBUX['Close'].ix['2015-01-03':'2018-07-01'].plot(label='SBUX CLOSE')
plt.legend()
# Out:
# /Users/yanyan/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#
# /Users/yanyan/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.figure(figsize=(12,6))
DNKN['Close'].ix['2015-01-03':'2018-07-01'].rolling(window=30).mean().plot(label='30 Day Avg')
DNKN['Close'].ix['2015-01-03':'2018-07-01'].plot(label='SBUX CLOSE')
plt.legend()
# Out:
# /Users/yanyan/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#
# /Users/yanyan/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
coffee_stocks.xs(key='Close',axis=1,level='Stock Info').corr()
# Out:
# Coffee Ticker      SBUX      DNKN
# Coffee Ticker
# SBUX           1.000000  0.080996
# DNKN           0.080996  1.000000
